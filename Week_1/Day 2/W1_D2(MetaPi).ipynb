# %%
#iteration >> loop >>> repetetion

# %%
# 2 loop
# while and for loops

# %%
n=5
while n>0:
  print(n)
  n=n-1
  print("Balstoff")
# Out:
# 5
# Balstoff
# 4
# Balstoff
# 3
# Balstoff
# 2
# Balstoff
# 1
# Balstoff

# %%
  # infinite loop if while is true
# if while is true it will not come out of loop
# so we use break statement

# %%
# Break Statement

# %%
while True:
  line=input('>')
  if line=='done':
    break
    print(line)
print('Done')
# Out:
# >#
# >hamza
# >done
# Done

# %%
# continue keyword

# %%
while True:
  line=input('>')
  if line[0]=='#':
    continue
  if line=='done':
      break
  print(line)
print('Done')
# Out:
# >#
# >hamza
# hamza
# >done
# Done

# %%
friends=['Adeel','Tauseef','Yousaf']
for friend in friends:
  print("Happy Ramadan",friend)  # if we write friends then it print whole list not go in the index
print("Done")
# Out:
# Happy Ramadan Adeel
# Happy Ramadan Tauseef
# Happy Ramadan Yousaf
# Done

# %%
count=0
total=0
for i in [3,41,12,9,74,15]:
  count =count+1
  print(i)

  total=total+i


print("total=",total)
print ("Total values Count",count)
# Out:
# 3
# 41
# 12
# 9
# 74
# 15
# total= 154
# Total values Count 6

# %% [markdown]
# # large and Small value

# %%
# find largest value
lv=0
for i in [3,41,12,9,74,15]:
  print(i)
  if i>lv:
    i=lv


print("largest value", i)
# Out:
# 3
# 41
# 12
# 9
# 74
# 15
# largest value 0

# %%
# sir solution
largest=None
print("Before",largest)
for i in [3,41,12,9,74,15]:
  if largest is None or i >largest:
    largest=i
  print("loop",i,largest)
print("Largest",largest)
# Out:
# Before None
# loop 3 3
# loop 41 41
# loop 12 41
# loop 9 41
# loop 74 74
# loop 15 74
# Largest 74

# %%
numbers = [3, 41, 12, 9, 74, 15]


largest_value = numbers[0]

for number in numbers:
    if number > largest_value:
        largest_value = number

print("The largest value is:", largest_value)

# %%
list= [3, 41, 12, 9, 74, 15]
lv=list[0]
for i in list:
  if i >lv:
    lv=i
print("Larges value", lv)
# Out:
# Larges value 74

# %%
x=None  # None= data type
type(x)
# Out:
# NoneType

# %%
# In programming we have unseen data type
# To counter this we use 'None '

# %%
# Max and min loop

sv =None
print("Before",sv)
for i in [3, 41, 12, 9, 74, 15]:
  if sv is None or i < sv:
    sv=i
  print("Loop",i,sv)
print("Smallest",sv)
# Out:
# Before None
# Smallest 3

# %%
list=[3, 41, 12, 9, 74, 15]
sv=list[0]
for i in list:
  if i<sv:
    sv=i
print("smallest", sv)
# Out:
# smallest 3

# %% [markdown]
# # Activity

# %%
#try 1
def hh():
  try:
    while True:
      line=input('>')
      line=int(line)
      line=line +line
      to_va=line
      if line=='done':
        break
        print(line)
  except:
    print("You entered the the wrong input")
hh()
print('Done')
print("Total",to_va)
#print("Count",to_c)
#print("Average",av)
# Out:
# >hamza
# You entered the the wrong input
# Done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-c8e92348a921> in <cell line: 15>()
#      13 hh()
#      14 print('Done')
# ---> 15 print("Total",to_va)
#      16 #print("Count",to_c)
#      17 #print("Average",av)
#
# NameError: name 'to_va' is not defined

# %%
#try 2
try:
  while True:
      line=input('>')
      if line=="str":
        print("Enter the correct Input")
      else:
        line
except:
  print("Enter the correct input ")

# %%
x= "hama"
type(x)
# Out:
# str

# %%
###### try 3
while True:

  try:
    line=input('>>')
    i=0
    line=int(line)
    for i in line:
      line = i+line
      coutnt =i+1
    print("total_sum", line)
    print("average", line/i)



  except:
    print("Please enter the correct input")
# Out:
# >>2
# Please enter the correct input
# Please enter the correct input
# Please enter the correct input
# Please enter the correct input
# Please enter the correct input
# Please enter the correct input
# Please enter the correct input
# Please enter the correct input
# Please enter the correct input
# Please enter the correct input
# Please enter the correct input

# %%
while True:
  line=input('>>')
  x= type(line)
  if x==str:
    print("enter correct i/p")
    break

  try:

    i=0
    line=int(line)
    for i in line:
      line = i+line
      coutnt =i+1

    print("total_sum", line)
    print("average", line/i)



  except:
    print("Please enter the correct input")
# Out:
# >>hamza
# Please enter the correct input
# >>2
# Please enter the correct input
# >>2
# Please enter the correct input
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8cb7b8a9a0c2> in <cell line: 1>()
#       1 while True:
# ----> 2   line=input('>>')
#       3   x= type(line)
#       4   if x=="str":
#       5     print("enter correct input")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
x=input("please enter the number ")
x=int(x)
for i in range(1, 10):
  result= x*i
  print(i)
# Out:
# please enter the number 2
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# Understand it
count=0
total=0
average=0

while True:
    line=input('>>')

    if line=="done":
        print("exit")
        break
    try:
        value=int(line)
        count =count+1
        total= total+value
        average = total/count
    except:
        print("Please enter the correct input")

print(total)
print(count)
print(average)
# Out:
# >>2
# >>2
# >>done
# exit
# 4
# 2
# 2.0

# %%
#####################################
number = 2
def print_multiplication_table(number, limit=10):
    # Print the header row
    print(f"Multiplication Table of {number}:")


    for i in range(1, limit + 1):
        result = number * i
        print(f"{number} x {i} = {result}")


print_multiplication_table(number)
# Out:
# Multiplication Table of 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
number= 2
print("Multiplication of Table ", number)
for i in range(1,11):
  result=number * i
  print(number, 'x', i, '=',result)
# Out:
# Multiplication of Table  2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
fruit = "banana"
print(fruit[-3])
print(len(fruit))
fruit[6]
# Out:
# a
# 6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-07aae96e4680> in <cell line: 4>()
#       2 print(fruit[-3])
#       3 print(len(fruit))
# ----> 4 fruit[6]
#
# IndexError: string index out of range

# %%
fruit="banana"
index=0
while index < len(fruit):
  letter=fruit[index]
  print(letter)
  index=index+1
# Out:
# b
# a
# n
# a
# n
# a

# %%
# activity 10
fruit='pear'
index= len(fruit)

while True:
  print(fruit[index-1])
  index=index-1
  if index==0:
    break
# Out:
# r
# a
# e
# p

# %%
### Slices
s="Monty Python"
print(s[0:5])
print(s[:5]) # it will start form starting python

print(s[6:12])

print(s[0:5:2])  # third i/p will be shows step

print(s[0:-5])
print("-5 to 0")
print(s[-5:0])
print(s[::-1])  # it will output the string in reverse
print(s[3:])  # start form index
print(s[:3])
# Out:
# Monty
# Monty
# Python
# Mny
# Monty P
# -5 to 0
#
# nohtyP ytnoM
# ty Python
# Mon

# %%
x= 'hello'
x[0]="j" # gives error
print(x[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-923582580fa8> in <cell line: 2>()
#       1 x= 'hello'
# ----> 2 x[0]="j"
#       3 print(x[0])
#
# TypeError: 'str' object does not support item assignment

# %%
x='hello'
y=("j"+x[1:])
print(y)
# Out:
# jello

# %%
x='hello'
print('j'+x[1:])
# Out:
# jello

# %%
x='hello'
print('j',x[1:])
# Out:
# j ello

# %%
x="jeollo"
count=0
for i in x:
  if i=='o':
    count=count+1
print("total'o' ", count)
# Out:
# total'o'  2

# %%
def count():
  x="jeollo"
count=0
for i in x:
  if x=='o':
    count=count+1
print("total'o' ", count)

# %%
# Acitivity 11
######################################################################
def count():
  x="jeollo"
  count=0
  for i in x:
    if x=='o':
      count=count+1
  print("total'o' ", count)

# %%
def count(str,ch):
  fruit=str
  count=0
  for char in fruit:
    if char == ch:
      count =count+1
  print(count)
count("aaaa","a")
# Out:
# 4

# %% [markdown]
# # in Opertator

# %%
# in operator
# in is boolean opertator

"a" in "banana"
"seed" in "banana"
# Out:
# False

# %%
ord('foo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-3b34f0998aab> in <cell line: 1>()
# ----> 1 print(ord(foo))
#       2 ord('foo')
#
# NameError: name 'foo' is not defined

# %%
word='c'
word <'banana'
# Out:
# False

# %%
word='b'
# Out:
# True

# %%
word=''

# %%
== # whole strings

< only matching characters

# %%
word='Pineapple'
word < 'banana'
# Out:
# True

# %%
word= "Pineapple"
if word < "banan"

# %%
word='P'
word < 'b'
# Out:
# True

# %%
ord('P')
# Out:
# 80

# %%
ord('b')
# Out:
# 98

# %%
# objects = str, int are all data types same as objects

x="hamza"
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
dir('Pineapple')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
stuff= "hello world"
type(stuff)
directory=dir(stuff)
print(directory)
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
stuff.upper()
# Out:
# 'HELLO WORLD'

# %%
# task practice all dir fuctions

# press ctr and method to see how to get arguments

# %%
x='form stephen.marrr@ ucl.ac.Sa sat Jan'
y=x.find(' ')
z=x.find('@')
print(y)
print(z)
print("Your email is:  "+ x[4:18])
# find fucntion find position int variabel
# Out:
# 4
# 18
# Your email is:   stephen.marrr

# %%
x.split()
# Out:
# ['form', 'stephen.marrr@', 'ucl.ac.Sa', 'sat', 'Jan']

# %%
y=x.split() # find work fomr the list
for i in y:
  print(i)
print(y[1])
# Out:
# form
# stephen.marrr@
# ucl.ac.Sa
# sat
# Jan
# stephen.marrr@

# %%
y=x.split()
print(y)
print(y[1])
# Out:
# ['form', 'stephen.marrr@', 'ucl.ac.Sa', 'sat', 'Jan']
# stephen.marrr@

# %%
# graph data bases
# selenium
# cipher query langr
# mislenium > automation tool

# %%
# How to make Real time 'draft' # pull data from web socket

# %%
# Activity 12a

# %%
#q1
# convert given strings into a list of words

x= " hello my name is hamza iqbal"
y=x.split()
print(y)
# now print the wnd last word
print(len(y))
print(y[-2])
print(y)
# Out:
# ['hello', 'my', 'name', 'is', 'hamza', 'iqbal']
# 6
# hamza

# %%
# q2
# lower case the first n characters the string.
string= "HELLO my name is hamza iqbal"
ch_to_lo=string[0:5]
print(ch_to_lo)
lower_chr=ch_to_lo.lower()
print(lower_chr)
# now we concatenate both the strings
print(lower_chr + string[5:len(string)])
# Out:
# HELLO
# hello
# hello my name is hamza iqbal

# %%
#q3
# Count and disply vowels of a given strings
string = 'axxexxixxoxxua'
count=0
for i in string:
  if i=='a':
    count= count+1
    print(i)
  if i=='e':
    count= count+1
    print(i)
  if i=='i':
    count= count+1
    print(i)
  if i=='o':
    count= count+1
    print(i)
  if i=='u':
    count= count+1
    print(i)
print("Total Count", count)
# Out:
# a
# e
# i
# o
# u
# a
# Total Count 6

# %%
#q3
# Count and disply vowels of a given strings
string = 'axxexxixxoxxuau'
count=0
for i in string:
  if i=='a' or i== 'e' or i=='i' or i=='o' or i=='u':
    count= count+1
    print(i)

print("Total Count", count)
# Out:
# a
# e
# i
# o
# u
# a
# u
# Total Count 7

# %%
string= "My name is Tommy"
y= string[::2]
print(y)
# Out:
# M aei om

# %%
string= "My name is Tommy"
y= string[::-2]
print(y)
# Out:
# ymTs mny

# %% [markdown]
# # Acvtiviy 12

# %%
string= "My name is Tommy"
print(string.find('o'))
# Out:
# 12

# %%
string= "             My name is Tommy "
print(string)
yy=string.strip()
print(yy)

z=yy.startswith('M')
print(z)
# Out:
#              My name is Tommy
# My name is Tommy
# True

# %%
z=string.startswith(' ')
print(z)
# Out:
# True
