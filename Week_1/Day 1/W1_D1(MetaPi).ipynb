# %%
print("hello world")
# Out:
# hello world

# %%
x=43
type(x)
print(type(x))
x=x+1
print(x)
# Out:
# <class 'int'>
# 44

# %%
# we can use double or single qoutes same meaning
print("hello")
print('hello')
# Out:
# hello
# hello

# %%
x="43"
print(type(x))
# Out:
# <class 'str'>

# %%
type(43)
type(43.4)
type("43")
type("hamza")
# Out:
# str

# %%
# if we have double qoutes in a string then we use triple qoutes

# %%
43x= 'hamza'
x@=444
# Out:
#   Cell In[15], line 1
#     43x= 'hamza'
#      ^
# SyntaxError: invalid decimal literal

# %%
x=pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x=pi
#
# NameError: name 'pi' is not defined

# %%
minute=59
minute/60
# Out:
# 0.9833333333333333

# %%
x=1
x+1
# Out:
# 2

# %%
5
x=5
x+1
# x=1

# %%
x=1+2**3/4+5
print(x)
# Out:
# 8.0

# %%
x=7//3
print(x)
# Out:
# 2

# %%
first_name= "Adeel"
Second='Zafar'
full_name= first_name + " " + Second
print(full_name)
# Out:
# Adeel Zafar

# %%
first="test "
second =3
print(first*second )
# Out:
# test test test

# %%
x=input("enter number ")
print(type(x))
# Out:
# enter number 33
# <class 'str'>

# %%
# we can pass argument to input functions
name=input("What is your name: ")
degree=input("What is your degree: ")
print("Here are the details you entered: ")
print(name)
print(degree)
# Out:
# What is your name: Hamza
# What is your degree: BS
# Here are the details you entered:
# Hamza
# BS

# %%
name=input("What is your name: \n)
degree=input("What is your degree: \n")
print("Here are the details you entered: ")
print(name)
print(degree)

# %%
x=int(input("Enter number: "))
# if we enter interger then its fine
# And if we enter string then it gives error
# Out:
# Enter number: "43"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 x=int(input("Enter number: "))
#
# ValueError: invalid literal for int() with base 10: '"43"'

# %%
# ctrl / automatically comment the line

# %%
# hamza
# umer
# buddie

# %%
#Activity 3

x=input("Enter your name: ")
print("Welcome "+ x)
# Out:
# Enter your name: Hamza
# Welcome Hamza

# %%
x=float(input("Enter number of hours you work today: "))
y=float(input("Enter per hour rate: "))
z= x*y
print("Your gross pay is: ", z)
# Out:
# Enter number of hours you work today: 10
# Enter per hour rate: 10
# Your gross pay is:  100.0

# %%
Cel_temp=float(input("Enter temp in Celcius: "))
far_temp= (Cel_temp * (9/5)) + 32
print("Far. Temp= ", far_temp)
# Out:
# Enter temp in Celcius: 1
# Far. Temp=  33.8

# %%
# Comparis operator
print(5==5)
# Out:
# True

# %%
x= "hamza"
y="umer"
print(x !=y )
print(x > y )
print(x < y )
print(x >= y )
print(x <= y )
print("Last ")


x is y
x is not y
# Out:
# True
# False
# True
# False
# True
# Last
# True

# %%
# block operators
x= 0
y= 1
print(x and y)

print(x or y)

print(not(x))
# Out:
# 0
# 1
# True

# %%
x=9
if x < 10:
    print("x is less than 10 ")
# Out:
# x is less than 10

# %%
x=8
if x%2 == 0:
    print("x is even")
else:
    print('x is odd')
# Out:
# x is even

# %%
x=20
y= 200
if x < y:
    print(" x is smaller ")
elif x > y:
    print(" x is greate")

else:
    print("Both are equal")
# Out:
#  x is smaller

# %%
x=2
y= 2
if x==y:
    print(" x and y are equal ")
else:
    if x > y:
        print(" x is greate")

    else:
        print("x is smaller ")
# Out:
#  x and y are equal

# %%
Cel_temp=input("Enter temp in Celcius: ")
try:
    Cel_temp=float(Cel_temp)   #### if you not enter this line it will gives error. Please convert this to float
    far_temp= (Cel_temp * (9/5)) + 32
    print("Far. Temp= ", far_temp)
except:
    print("Please enter a number not string or special character: ")
# Out:
# Enter temp in Celcius: ha
# Please enter a number not string or special character:

# %%
inp= input("Enter a far temp: ")
try:
    fahr= float(inp)
    cel= (fahr-32) * (5/9)
    print(cel)
except:
    print("Please enter a number")
# Out:
# Enter a far temp: 32
# 0.0

# %%
# short circuits evaluations
#   to your own benefit for evaluatin and testing

# %%
score= input(" Enter a score between 0.0 and 1.0: ")
try:
    score=
    if x>=0.0 and x<=1.0   ###  %%%%%%%%%%%%%
        print(" Enter a score between 0.0 and 1.0: ")
        else x == 0.0:
        print("Fail")
    elif x== 0.5:
        print("Stisfactory ")
    elif x==1.0:
        print("Pass")
except:

    print("Please enter a number ")
# Out:
#  Enter a score between 0.0 and 1.0: 0.5
# Please enter a number

# %%
x = float(input(" Enter a score between 0.0 and 1.0: "))
if x>1:
    print(" Enter a score between 0.0 and 1.0: ")
if x<0:
    print("Enter a valid number")
if x == 0.0:
    print("Fail")
if x== 0.5:
    print("Stisfactory ")
if x==1.0:
    print("Pass")
# Out:
#  Enter a score between 0.0 and 1.0: 5
#  Enter a score between 0.0 and 1.0:

# %%
x = float(input(" Enter a score between 0.0 and 1.0: "))
if x>1:
    print(" Enter a score between 0.0 and 1.0: ")
elif x<0:
    print("Enter a valid number")
elif x >= 0.9:
    print("A")
elif x >= 0.8:
    print("B ")
elif x >= 0.7:
    print("C")
elif x >= 0.6:
    print("D")
elif x < 0.6:
    print("F")
# Out:
#  Enter a score between 0.0 and 1.0: 0.6
# D

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
degrees =45
radians = degrees / 360.0 *2 *math.pi
rad_sin=math.sin(radians)
print(radians)
print(rad_sin)
# Out:
# 0.7853981633974483
# 0.7071067811865476

# %%
from math import pi
# if libraray have big size only import specific libraries only

# %%
pi
# Out:
# 3.141592653589793

# %%
from math import  ("press tab to see all fuctions ")

# %%
from math import pi, sin,

# %%
import random

# %%
for i in range(10):
    x= random.random() # random contain many fuctions we are using only random functions
    print(x)
# Out:
# 0.7654822988325903
# 0.1981726671484353
# 0.4710230163192183
# 0.3184288176245207
# 0.8293576294257047
# 0.43339925477303065
# 0.013821097427773932
# 0.9731380323214345
# 0.518461020797231
# 0.9030298720583656

# %%
# to define your own range
for i in range(10):
    x= random.randint(1,10) # Both are included
    print(x)
# Out:
# 6
# 3
# 6
# 5
# 1
# 7
# 7
# 10
# 7
# 9

# %%
# random. choice # you can pass list
t=[1,2,3]   # it will use following list randomly
# behind this randomniztions algorithms is applied then choose the following list
random.choice(t)
# Out:
# 2

# %%
# random. choice # you can pass list
t=[1.3,2.44,3.6666]
random.choice(t)
# Out:
# 1.3

# %%
def print_fn(f_n, l_n):
    return(f_n,l_n)
print("hamza","iqbal")
# Out:
# hamza iqbal

# %%
def abc(a,b):
    return a,b
a= abc(a,b) # a would b tuple
a,b= abc(a,b)# a and b would b strings

# %%
# activity 5
hours= input("Enter no. of hours you work: ")
hours=(hours)
if hours >= 1 and hours <= 40:
    gp= 10.50*(hours)
    print("Your gross pay is: ", gp)

if hours>40:
    gp1= 10.5*40
    gp2=10.5*1.5*(hours-40)
    print("Your gross pay is: ", gp1+gp2)
# Out:
# Enter no. of hours you work: 45
# Your gross pay is:  498.75

# %%
hours= input("Enter no. of hours you work")
try:
    hours=int(hours)
    if hours >= 1 and hours <= 40:
        gp= 10.50*(hours)
        print("Your gross pay is: ", gp)

    if hours>40:
        gp1= 10.5*40
        gp2=10.5*1.5*(hours-40)
        print("Your gross pay is: ", gp1+gp2)

except:
    print(" Please enter valid number: ")
# Out:
# Enter no. of hours you work45
# Your gross pay is:  498.75

# %%
# Activity 6

for i in range(10):
    x=random.random()
    print(x)
# Out:
# 0.6753587761885643
# 0.4210554642956642
# 0.7891619920076354
# 0.7178735475795771
# 0.8754533584958422
# 0.16958433247410998
# 0.07536693436758124
# 0.1811710797379178
# 0.25419305628932787
# 0.7139844411866847

# %%
# Activity 7
print_lyric()
def print_lyric():
    print("I am okay")
    print("I work all day")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Activity 7
# ----> 2 print_lyric()
#       3 def print_lyric():
#       4     print("I am okay")
#
# NameError: name 'print_lyric' is not defined

# %%
print_number()
def print_number():
    print("x")
    print("y")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 print_number()
#       2 def print_number():
#       3     print("x")
#
# NameError: name 'print_number' is not defined

# %%
# Activity 8

def computepay():

    if hours >= 1 and hours <= 40:
        gp= 10.50*(hours)
        print("Your gross pay is: ", gp)

    if hours>40:
        gp1= 10.5*40
        gp2=10.5*1.5*(hours-40)
        print("Your gross pay is: ", gp1+gp2)

hours= input("Enter no. of hours you work: ")
hours=float(hours)
computepay()
# Out:
# Enter no. of hours you work: 45
# Your gross pay is:  498.75
